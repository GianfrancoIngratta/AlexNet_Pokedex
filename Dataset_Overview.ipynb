# %% [markdown]
# <a href="https://colab.research.google.com/github/jabb4/AlexNet_Pokedex/blob/main/Dataset_Overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import opendatasets as od
from os import listdir
import os

# %% [markdown]
# # The Pokéon image dataset
#
# We used as source of images the website kaggle, which has a lot of datasets to work with. Here's the download and the display of the dataset.

# %%
od.download("https://www.kaggle.com/datasets/thedagger/pokemon-generation-one")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: gianfrancoingratta
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 2.15G/2.15G [00:23<00:00, 99.5MB/s]

# %% [markdown]
# We chose to operate by the moment on the first generation Pokédex, which counts a total of 150 different Pokémons (so 150 different species).

# %%
root_path = '/content/pokemon-generation-one/dataset/'
classes = os.listdir(root_path)
count=0
count_dict = {}
print(f'Total number of pokemons: {len(classes)}')
for pokemon in classes:
    dir_path = os.path.join(root_path, pokemon)
    count+=len(os.listdir(dir_path))
    count_dict[pokemon] = len(os.listdir(dir_path))
# Out:
# Total number of pokemons: 150

# %% [markdown]
# The entries of the dataset are the following, divided per each Pokémon species.

# %%
pd.Series(count_dict).sort_values(ascending=False).plot.bar(figsize=(30,10))

# %% [markdown]
# Since the first main goal of the repository is to test the proper classification of the algorithm itself, the analysis was performed on the 5 Pokémons which had the largest number of entries:
# - Mewtwo
# - Pikachu
# - Charmander
# - Bulbasaur
# - Squirtle
